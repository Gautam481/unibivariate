# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
#  #1Replace the none value

# %%
#1-replace 0 in salary because they are not placed

# %%
#2-delete the null rows because there is no datas in entire columns so delete the 2rows

# %%
dataset.isnull().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             2
# gender            2
# ssc_p             2
# ssc_b             2
# hsc_p             2
# hsc_b             2
# hsc_s             2
# degree_p          2
# degree_t          2
# workex            2
# etest_p           2
# specialisation    2
# mba_p             2
# status            2
# salary            0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# #2How many of them are not placed

# %%
df=dataset[dataset['status']=='Not Placed']

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3      4.0      M   56.0  Central   52.0  Central   Science     52.00
# 5      6.0      M   55.0   Others   49.8   Others   Science     67.25
# 6      7.0      F   46.0   Others   49.2   Others  Commerce     79.00
# 11    10.0      M   58.0  Central   70.0  Central  Commerce     61.00
# 14    13.0      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 200  199.0      F   67.0  Central   70.0  Central  Commerce     65.00
# 203  202.0      M   54.2  Central   63.0   Others   Science     58.00
# 208  207.0      M   41.0  Central   42.0  Central   Science     60.00
# 210  209.0      F   43.0  Central   60.0   Others   Science     65.00
# 216  215.0      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
df.count()
# Out:
# sl_no             67
# gender            67
# ssc_p             67
# ssc_b             67
# hsc_p             67
# hsc_b             67
# hsc_s             67
# degree_p          67
# degree_t          67
# workex            67
# etest_p           67
# specialisation    67
# mba_p             67
# status            67
# salary            67
# dtype: int64

# %% [markdown]
# #3find the reason for nonplacement from the dataset

# %%
quan=[]
qual=[]
for columnName in df.columns:
    if (df[columnName].dtype=='O'):
        quan.append(columnName)
    else:
        qual.append(columnName)

# %%
qual
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
df[qual]
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p  salary
# 3      4.0   56.0   52.0     52.00    66.00  59.43     0.0
# 5      6.0   55.0   49.8     67.25    55.00  51.58     0.0
# 6      7.0   46.0   49.2     79.00    74.28  53.29     0.0
# 11    10.0   58.0   70.0     61.00    54.00  52.21     0.0
# 14    13.0   47.0   55.0     65.00    62.00  65.04     0.0
# ..     ...    ...    ...       ...      ...    ...     ...
# 200  199.0   67.0   70.0     65.00    88.00  71.96     0.0
# 203  202.0   54.2   63.0     58.00    79.00  58.44     0.0
# 208  207.0   41.0   42.0     60.00    97.00  53.39     0.0
# 210  209.0   43.0   60.0     65.00    92.66  62.92     0.0
# 216  215.0   62.0   58.0     53.00    89.00  60.22     0.0
#
# [67 rows x 7 columns]

# %%
df[df['degree_p']>80]
# Out:
# Empty DataFrame
# Columns: [sl_no, gender, ssc_p, ssc_b, hsc_p, hsc_b, hsc_s, degree_p, degree_t, workex, etest_p, specialisation, mba_p, status, salary]
# Index: []

# %%
df[df['hsc_p']>80]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 101  100.0      M   54.0  Central   82.0  Others  Commerce      63.0
#
#      degree_t workex  etest_p specialisation  mba_p      status  salary
# 101  Sci&Tech     No     50.0        Mkt&Fin  59.47  Not Placed     0.0

# %% [markdown]
# #4what kind of relation between salary and mba_p

# %%
df1 = dataset[['salary', 'mba_p']]

# %%
df1.corr()
# Out:
#           salary     mba_p
# salary  1.000000  0.139823
# mba_p   0.139823  1.000000

# %% [markdown]
# #5which specialization is getting minimum salary

# %%
df2=dataset[['specialisation','salary']]

# %%
df2.min()
# Out:
# specialisation    Mkt&Fin
# salary                  0
# dtype: object

# %%
#6 how many of them getting above 50000 salary

# %%
dfsal=dataset[dataset['salary']>500000]

# %%
dfsal
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 121  120.0      M   60.8  Central  68.40  Central  Commerce      64.6
# 152  151.0      M   71.0  Central  58.66  Central   Science      58.0
# 179  178.0      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 121  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 152   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 179  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
#7Test the anova between etset_p & mba_p at significance level at 5%

# %%
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
#there is no significant difference because significant level need to be 5%

# %% [markdown]
# #8 Test the similarity between the degree_t(sci&tech) and specialisation(mkt&hr) with respect to salary at significant level at5%

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
ano2=ols('salary~degree_t+specialisation',data=dataset).fit()
two=sm.stats.anova_lm(ano2,type=2)

# %%
two
# Out:
#                    df        sum_sq       mean_sq          F    PR(>F)
# degree_t          2.0  8.032042e+10  4.016021e+10   1.816476  0.165131
# specialisation    1.0  3.815378e+11  3.815378e+11  17.257239  0.000047
# Residual        211.0  4.664969e+12  2.210886e+10        NaN       NaN

# %%
#there is no significant difference because significant level need to be 5%

# %%
#9 convert the normal distribution to standard normal distribution for salary column

# %%
#normal distribution

# %%
import seaborn as sns
sns.distplot(dataset["salary"])
# Out:
# C:\Users\admin\Anaconda3\envs\MLClustering\lib\site-packages\ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
#standard normal distribution

# %%
def stdNBgraph(dataset):
    #convert to standard normal deviation using formula
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    
    values=[i for i in dataset]
    z_score=[((j-mean)/std)for j in values]
    sns.displot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset['salary'])

# %%
#10 what is the probability density function of a salary from 700000-900000

# %%
def pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='green') #distplot gives the chart and we are giving datasetfor datas,kde=true is for kernel distribution (curve)
    pyplot.axvline(startrange,color='Red') #range starting lne
    pyplot.axvline(endrange,color='Red') #range ending lne
    #create a sample data
    sample=dataset
    #calculate parameters
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f,Standard Deviatiion=%.3f' %(sample_mean,sample_std))
    #define the distribution(normal distribution)
    dist=norm(sample_mean,sample_std)

    #so outcomes we can use traditional for loop but here we use one liner for loop

    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value) for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
pdf_probability(dataset['salary'],700000,900000)
# Out:
# C:\Users\admin\Anaconda3\envs\MLClustering\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# Mean=198702.326,Standard Deviatiion=154780.927
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %% [markdown]
# #11 Test the similarity between the degree_t(sci&tech) and with respect to etest_p & mba_p at significant level at5%

# %%
'height ~ C(Fertilizer) + C(Watering) +\
    C(Fertilizer):C(Watering)'

'degree_t ~ C(etest_p) + C(mba_p) +\C(etest_p):C(mba_p)'

# %%
import scipy.stats as stats
stats.f_oneway(dataset['degree_t'],dataset['mba_p'],dataset['etest_p'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4884\3356147344.py in <module>
#       1 import scipy.stats as stats
# ----> 2 stats.f_oneway(dataset['degree_t'],dataset['mba_p'],dataset['etest_p'])
#
# ~\Anaconda3\envs\MLClustering\lib\site-packages\scipy\stats\stats.py in f_oneway(axis, *args)
#    3604         raise TypeError(f'at least two inputs are required; got {len(args)}.')
#    3605
# -> 3606     args = [np.asarray(arg, dtype=float) for arg in args]
#    3607
#    3608     # ANOVA on N groups, each in its own array
#
# ~\Anaconda3\envs\MLClustering\lib\site-packages\scipy\stats\stats.py in <listcomp>(.0)
#    3604         raise TypeError(f'at least two inputs are required; got {len(args)}.')
#    3605
# -> 3606     args = [np.asarray(arg, dtype=float) for arg in args]
#    3607
#    3608     # ANOVA on N groups, each in its own array
#
# ...

# %%
#12 which parameteris highly correalated with salary

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def cal_vif(X):
   #Calculating VIF
    vif=pd.DataFrame()
    vif["variables"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return (vif)

# %%
cal_vif(dataset[["ssc_p","hsc_p","degree_p","salary","etest_p"]])
# Out:
#   variables        VIF
# 0     ssc_p  71.644437
# 1     hsc_p  54.750663
# 2  degree_p  81.419329
# 3    salary   3.422882
# 4   etest_p  30.843155

# %%
#cal_vif(dataset[["ssc_p","hsc_p","degree_p","salary","etest_p"]])   #"ssc_p","hsc_p","degree_p",
cal_vif(dataset[["salary","etest_p"]])
# Out:
#   variables       VIF
# 0    salary  2.745261
# 1   etest_p  2.745261

# %%
cal_vif(dataset[["salary","ssc_p"]])
# Out:
#   variables       VIF
# 0    salary  3.248087
# 1     ssc_p  3.248087

# %%
cal_vif(dataset[["salary","hsc_p"]])
# Out:
#   variables       VIF
# 0    salary  3.116876
# 1     hsc_p  3.116876

# %%
cal_vif(dataset[["salary","degree_p"]])
# Out:
#   variables       VIF
# 0    salary  2.940539
# 1  degree_p  2.940539

# %%
etest_p is nearly correlated to salary
